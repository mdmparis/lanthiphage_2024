# %%
import pandas as pd

# %%
article=pd.read_table('Lanthiphage_2024_ref.csv',sep=';',encoding = "ISO-8859-1")
article['Author_list']=article.Author.map(lambda x: x.split(";"))
Author=pd.DataFrame({'First':[],'Second':[],"Rank":[],"Title":[]})
for i in article.index.to_list():
    liste=article.Author_list[i]
    n=0
    article_name=article.Title[i]
    for j in range(len(liste)):
        last=article.Author_list[i][j].split(",")[0]
        first=article.Author_list[i][j].split(", ")[1].split(" ")[0]
        if n==0:
            rank='first'
        elif n==len(liste)-1:
            rank='last'
        else:
            rank='mid'
        author=pd.DataFrame({'First':[first],'Second':[last],'Rank':[rank],'Title':[article_name]})
        Author=pd.concat([Author,author])
        n+=1
        
        
len(article)
# Out:
# 53

# %%
from unidecode import unidecode

Author['First']=Author.First.map(unidecode)
Author['First']=Author.First.map(lambda x: x.lower())
Author['Second']=Author.Second.map(unidecode)
Author['Second']=Author.Second.map(lambda x: x.lower())
Author['First']=Author.First.map(lambda x: x.replace(" ",""))
Author['First']=Author.First.map(lambda x: x.replace("-",""))
Author=Author.reset_index(drop=True)

# %%
name_gender=pd.read_table('name_gender_dataset.csv',sep=',')
name_gender['Name']=name_gender.Name.map(unidecode)
name_gender['Name']=name_gender.Name.map(lambda x: x.lower())
name_gender['Name']=name_gender.Name.map(lambda x: x.replace(" ",""))
name_gender['Name']=name_gender.Name.map(lambda x: x.replace("-",""))
name_gender=name_gender.pivot_table(index='Name',columns='Gender',values='Count',aggfunc=sum).fillna(0)
name_gender['Name']=name_gender.index
name_gender['Name']=name_gender.index
name_gender['Ratio_M']=name_gender.M/(name_gender.M+name_gender.F)
name_gender['Total_name']=name_gender.M+name_gender.F
name_gender=name_gender.loc[name_gender.Total_name>5]
name_gender['Gender']="U"
name_gender.loc[name_gender.Ratio_M>0.9,'Gender']='M'
name_gender.loc[name_gender.Ratio_M<0.10,'Gender']='F'
name_gender.reset_index(drop=True,inplace=True)
# Out:
# /tmp/ipykernel_465/3470288348.py:6: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   name_gender=name_gender.pivot_table(index='Name',columns='Gender',values='Count',aggfunc=sum).fillna(0)
# /tmp/ipykernel_465/3470288348.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name_gender['Gender']="U"

# %%
for i in Author.index.to_list():
    Author.loc[i,'isin_db']=len(name_gender.loc[name_gender.Name==Author.First[i]])
Author
# Out:
#        First        Second   Rank  \
# 0     ja!nos      ba(c)rdy  first
# 1      doris  van bergeijk  first
# 2    barbara       terlouw    mid
# 3     marnix        medema    mid
# 4     gilles     van wezel   last
# ..       ...           ...    ...
# 442      rob         patro   last
# 443    boris      muzellec  first
# 444    maria     teleaczuk    mid
# 445  vincent        cabeli    mid
# 446  mathieu       andreux   last
#
#                                                  Title  isin_db
# 0                      Bioactive Microbial Metabolites      0.0
# 1    Ecology and genomics of Actinobacteria: new co...      1.0
# 2    Ecology and genomics of Actinobacteria: new co...      1.0
# 3    Ecology and genomics of Actinobacteria: new co...      0.0
# 4    Ecology and genomics of Actinobacteria: new co...      1.0
# ..                                                 ...      ...
# 442  A Bayesian framework for inter-cellular inform...      1.0
# 443  PyDESeq2: a python package for bulk RNA-seq di...      1.0
# 444  PyDESeq2: a python package for bulk RNA-seq di...      1.0
# 445  PyDESeq2: a python package for bulk RNA-seq di...      1.0
# 446  PyDESeq2: a python package for bulk RNA-seq di...      1.0
#
# [447 rows x 5 columns]

# %%
Author0=Author.loc[Author.isin_db==0,]
Author=Author.loc[Author.isin_db!=0,]
Author=Author.merge(name_gender[['Name','Gender']],left_on='First',right_on='Name')

# %%
Author0
# Out:
#        First     Second   Rank  \
# 0     ja!nos   ba(c)rdy  first
# 3     marnix     medema    mid
# 5     atanas   atanasov  first
# 8    claudiu    supuran   last
# 13   rajnish      verma  first
# ..       ...        ...    ...
# 430       e.       seno    mid
# 431       r.        rao    mid
# 432       b.    schoner   last
# 434    joost   willemse    mid
# 441    hirak     sarkar    mid
#
#                                                  Title  isin_db
# 0                      Bioactive Microbial Metabolites      0.0
# 3    Ecology and genomics of Actinobacteria: new co...      0.0
# 5    Natural products in drug discovery: advances a...      0.0
# 8    Natural products in drug discovery: advances a...      0.0
# 13   Microbial Natural Products: Recent Insights in...      0.0
# ..                                                 ...      ...
# 430  Plasmid cloning vectors for the conjugal trans...      0.0
# 431  Plasmid cloning vectors for the conjugal trans...      0.0
# 432  Plasmid cloning vectors for the conjugal trans...      0.0
# 434  The SepF-like proteins SflA and SflB prevent e...      0.0
# 441  A Bayesian framework for inter-cellular inform...      0.0
#
# [86 rows x 5 columns]

# %%
Author
# Out:
#         First         Second   Rank  \
# 0     kaitlyn      kortright  first
# 1    benjamin           chan    mid
# 2    benjamin         bolduc  first
# 3    jonathan           koff    mid
# 4    jonathan        messika    mid
# ..        ...            ...    ...
# 442   mathieu        blondel    mid
# 443     peter   prettenhofer    mid
# 444       ron          weiss    mid
# 445      jake     vanderplas    mid
# 446    willem       waegeman    mid
#
#                                                  Title  isin_db      Name  \
# 0    Phage Therapy: A Renewed Approach to Combat An...      1.0   kaitlyn
# 1    Phage Therapy: A Renewed Approach to Combat An...      1.0  benjamin
# 2    vConTACT: an iVirus tool to classify double-st...      1.0  benjamin
# 3    Phage Therapy: A Renewed Approach to Combat An...      1.0  jonathan
# 4    Pneumonia-Specific Escherichia coli with Disti...      1.0  jonathan
# ..                                                 ...      ...       ...
# 442           Scikit-learn: Machine Learning in Python      1.0   mathieu
# 443           Scikit-learn: Machine Learning in Python      1.0     peter
# 444           Scikit-learn: Machine Learning in Python      1.0       ron
# 445           Scikit-learn: Machine Learning in Python      1.0      jake
# 446  Algebraic shortcuts for leave-one-out cross-va...      1.0    willem
#
#     Gender
# 0        F
# 1        M
# 2        M
# 3        M
# 4        M
# ..     ...
# 442      M
# 443      M
# 444      M
# 445      M
# 446      M
#
# [447 rows x 7 columns]

# %%
Author0.loc[Author0.Rank.isin(['last','first'])]
# Out:
#             First    Second   Rank  \
# 0          ja!nos  ba(c)rdy  first
# 5          atanas  atanasov  first
# 8         claudiu   supuran   last
# 13        rajnish     verma  first
# 15     ha(c)loase   georjon  first
# 17     ha(c)loase   georjon  first
# 55         marnix    medema  first
# 57         marnix    medema  first
# 92          linyi       gao  first
# 221       tilmann     weber   last
# 310        marnix    medema   last
# 326        jeella     acedo  first
# 332      chaoxian       bai  first
# 340  va(c)ronique   ongenae  first
# 362     pieterjan  ceyssens  first
# 376         milot   mirdita  first
# 395  va(c)ronique   ongenae  first
# 410     christiam   camacho  first
# 417      kazutaka     katoh  first
# 427            m.   bierman  first
# 432            b.   schoner   last
#
#                                                  Title  isin_db
# 0                      Bioactive Microbial Metabolites      0.0
# 5    Natural products in drug discovery: advances a...      0.0
# 8    Natural products in drug discovery: advances a...      0.0
# 13   Microbial Natural Products: Recent Insights in...      0.0
# 15   The highly diverse antiphage defence systems o...      0.0
# 17   Genomic characterization of the antiviral arse...      0.0
# 55   Computational approaches to natural product di...      0.0
# 57   Mining genomes to illuminate the specialized c...      0.0
# 92   Diverse enzymatic activities mediate antiviral...      0.0
# 221  antiSMASH 6.0: improving cluster detection and...      0.0
# 310  MIBiG 3.0: a community-driven effort to annota...      0.0
# 326  O-Methyltransferase-Mediated Incorporation of ...      0.0
# 332  CUBIC: A Versatile Cumate-Based Inducible CRIS...      0.0
# 340  Genome sequence and characterization of Strept...      0.0
# 362  The Phage-Encoded N-Acetyltransferase Rac Medi...      0.0
# 376  MMseqs2 desktop and local web server app for f...      0.0
# 395  Genome sequence and characterization of Strept...      0.0
# 410              BLAST+: architecture and applications      0.0
# 417  MAFFT: a novel method for rapid multiple seque...      0.0
# 427  Plasmid cloning vectors for the conjugal trans...      0.0
# 432  Plasmid cloning vectors for the conjugal trans...      0.0

# %%
Author0=Author0.loc[Author0.Rank.isin(['last','first'])].reset_index(drop=True)
Author0
# Out:
#            First    Second   Rank  \
# 0         ja!nos  ba(c)rdy  first
# 1         atanas  atanasov  first
# 2        claudiu   supuran   last
# 3        rajnish     verma  first
# 4     ha(c)loase   georjon  first
# 5     ha(c)loase   georjon  first
# 6         marnix    medema  first
# 7         marnix    medema  first
# 8          linyi       gao  first
# 9        tilmann     weber   last
# 10        marnix    medema   last
# 11        jeella     acedo  first
# 12      chaoxian       bai  first
# 13  va(c)ronique   ongenae  first
# 14     pieterjan  ceyssens  first
# 15         milot   mirdita  first
# 16  va(c)ronique   ongenae  first
# 17     christiam   camacho  first
# 18      kazutaka     katoh  first
# 19            m.   bierman  first
# 20            b.   schoner   last
#
#                                                 Title  isin_db
# 0                     Bioactive Microbial Metabolites      0.0
# 1   Natural products in drug discovery: advances a...      0.0
# 2   Natural products in drug discovery: advances a...      0.0
# 3   Microbial Natural Products: Recent Insights in...      0.0
# 4   The highly diverse antiphage defence systems o...      0.0
# 5   Genomic characterization of the antiviral arse...      0.0
# 6   Computational approaches to natural product di...      0.0
# 7   Mining genomes to illuminate the specialized c...      0.0
# 8   Diverse enzymatic activities mediate antiviral...      0.0
# 9   antiSMASH 6.0: improving cluster detection and...      0.0
# 10  MIBiG 3.0: a community-driven effort to annota...      0.0
# 11  O-Methyltransferase-Mediated Incorporation of ...      0.0
# 12  CUBIC: A Versatile Cumate-Based Inducible CRIS...      0.0
# 13  Genome sequence and characterization of Strept...      0.0
# 14  The Phage-Encoded N-Acetyltransferase Rac Medi...      0.0
# 15  MMseqs2 desktop and local web server app for f...      0.0
# 16  Genome sequence and characterization of Strept...      0.0
# 17              BLAST+: architecture and applications      0.0
# 18  MAFFT: a novel method for rapid multiple seque...      0.0
# 19  Plasmid cloning vectors for the conjugal trans...      0.0
# 20  Plasmid cloning vectors for the conjugal trans...      0.0

# %%
Author0=Author0.loc[Author0.Rank.isin(['last','first'])].reset_index(drop=True)
Author0['Gender']=['M','M','M','M','F','F','M','M','M','M','M','F','U','F','M','M','F','M','M','U','F']
Author0
# Out:
#            First    Second   Rank  \
# 0         ja!nos  ba(c)rdy  first
# 1         atanas  atanasov  first
# 2        claudiu   supuran   last
# 3        rajnish     verma  first
# 4     ha(c)loase   georjon  first
# 5     ha(c)loase   georjon  first
# 6         marnix    medema  first
# 7         marnix    medema  first
# 8          linyi       gao  first
# 9        tilmann     weber   last
# 10        marnix    medema   last
# 11        jeella     acedo  first
# 12      chaoxian       bai  first
# 13  va(c)ronique   ongenae  first
# 14     pieterjan  ceyssens  first
# 15         milot   mirdita  first
# 16  va(c)ronique   ongenae  first
# 17     christiam   camacho  first
# 18      kazutaka     katoh  first
# 19            m.   bierman  first
# 20            b.   schoner   last
#
#                                                 Title  isin_db Gender
# 0                     Bioactive Microbial Metabolites      0.0      M
# 1   Natural products in drug discovery: advances a...      0.0      M
# 2   Natural products in drug discovery: advances a...      0.0      M
# 3   Microbial Natural Products: Recent Insights in...      0.0      M
# 4   The highly diverse antiphage defence systems o...      0.0      F
# 5   Genomic characterization of the antiviral arse...      0.0      F
# 6   Computational approaches to natural product di...      0.0      M
# 7   Mining genomes to illuminate the specialized c...      0.0      M
# 8   Diverse enzymatic activities mediate antiviral...      0.0      M
# 9   antiSMASH 6.0: improving cluster detection and...      0.0      M
# 10  MIBiG 3.0: a community-driven effort to annota...      0.0      M
# 11  O-Methyltransferase-Mediated Incorporation of ...      0.0      F
# 12  CUBIC: A Versatile Cumate-Based Inducible CRIS...      0.0      U
# 13  Genome sequence and characterization of Strept...      0.0      F
# 14  The Phage-Encoded N-Acetyltransferase Rac Medi...      0.0      M
# 15  MMseqs2 desktop and local web server app for f...      0.0      M
# 16  Genome sequence and characterization of Strept...      0.0      F
# 17              BLAST+: architecture and applications      0.0      M
# 18  MAFFT: a novel method for rapid multiple seque...      0.0      M
# 19  Plasmid cloning vectors for the conjugal trans...      0.0      U
# 20  Plasmid cloning vectors for the conjugal trans...      0.0      F

# %%
author_tot=pd.concat([Author,Author0])
author_tot=author_tot.loc[author_tot.Rank.isin(['first','last'])]
author_tot.loc[(author_tot.First=='rotem')&(author_tot.Second==' sorek'),'Gender']='M'
author_tot.loc[(author_tot.First=='adi')&(author_tot.Second=='millman'),'Gender']='F'
author_tot.loc[(author_tot.First=='kai')&(author_tot.Second=='blin'),'Gender']='M'
author_tot.loc[(author_tot.First=='bailey')&(author_tot.Second=='bonet'),'Gender']='F'
author_tot.loc[(author_tot.First=='innes')&(author_tot.Second=='jhon'),'Gender']='M'
author_tot.loc[(author_tot.First=='le')&(author_tot.Second=='zhang'),'Gender']='F'
author_tot.loc[(author_tot.First=='avi')&(author_tot.Second=='srivastava'),'Gender']='M'

# %%
author_tot.loc[author_tot.Gender=='U']
# Out:
#        First   Second   Rank  \
# 12  chaoxian      bai  first
# 19        m.  bierman  first
#
#                                                 Title  isin_db Name Gender
# 12  CUBIC: A Versatile Cumate-Based Inducible CRIS...      0.0  NaN      U
# 19  Plasmid cloning vectors for the conjugal trans...      0.0  NaN      U

# %%
author_tot.groupby('Rank').Gender.value_counts(normalize=True)
# Out:
# Rank   Gender
# first  M         0.584906
#        F         0.377358
#        U         0.037736
# last   M         0.765957
#        F         0.234043
# Name: proportion, dtype: float64

# %%
author_tot.loc[author_tot.Gender=='U']
# Out:
#              First         Second   Rank  \
# 180            jie            pan  first
# 181            yue           wang  first
# 7            akiyo           suga  first
# 12   antimicrobial  collaborators  first
# 20        colocoli          group   last
# 23        colocoli          group   last
# 24           chili           chiu  first
#
#                                                  Title  isin_db Name Gender
# 180  GSPHI: A novel deep learning model for predict...      1.0  jie      U
# 181  An Effective Model for Predicting Phage-Host I...      1.0  yue      U
# 7    Manipulating Interactions between T4 Phage Lon...      0.0  NaN      U
# 12   Global burden of bacterial antimicrobial resis...      0.0  NaN      U
# 20   Pneumonia-Specific Escherichia coli with Disti...      0.0  NaN      U
# 23   Bacteriophage LM33_P1, a fast-acting weapon ag...      0.0  NaN      U
# 24   napari: a Python Multi-Dimensional Image Viewe...      0.0  NaN      U

# %%
author_tot.loc[~author_tot.First.isin(['colocoli','antimicrobial'])].groupby('Rank').Gender.value_counts(normalize=False)
# Out:
# Rank   Gender
# first  M         52
#        F         25
#        U          4
# last   M         61
#        F         12
# Name: Gender, dtype: int64

# %%
author_tot.loc[author_tot.Rank=='last']
# Out:
#          First     Second  Rank  \
# 7         paul     turner  last
# 13      robert   schooley  last
# 29     bernard   de baets  last
# 33        yves     briers  last
# 34        yves     briers  last
# ..         ...        ...   ...
# 17     yitheng      chooi  last
# 20    colocoli      group  last
# 21  lhousseine     touqui  last
# 22  jeandamien     ricard  last
# 23    colocoli      group  last
#
#                                                 Title  isin_db     Name Gender
# 7   Phage Therapy: A Renewed Approach to Combat An...      1.0     paul      M
# 13  Phage therapy: From biological mechanisms to f...      1.0   robert      M
# 29  Algebraic shortcuts for leave-one-out cross-va...      1.0  bernard      M
# 33  Digital phagograms: predicting phage infectivi...      1.0     yves      M
# 34  Identification of Phage Receptor-Binding Prote...      1.0     yves      M
# ..                                                ...      ...      ...    ...
# 17  clinker & clustermap.js: automatic generation ...      0.0      NaN      M
# 20  Pneumonia-Specific Escherichia coli with Disti...      0.0      NaN      U
# 21  Bacteriophages can treat and prevent Pseudomon...      0.0      NaN      M
# 22  Treatment of Highly Virulent Extraintestinal P...      0.0      NaN      M
# 23  Bacteriophage LM33_P1, a fast-acting weapon ag...      0.0      NaN      U
#
# [75 rows x 7 columns]

# %%
author_tot.Rank.value_counts()
# Out:
# first    82
# last     75
# Name: Rank, dtype: int64

# %%
Author0.to_csv('Author0.tsv',sep='\t')

# %%
Author2.loc[(Author2.Rank.isin(['first','last']))&(Author2.Gender=="U")]
Author2.groupby('Rank').Gender.value_counts()
# Out:
# Rank   Gender
# first  M          96
#        F          80
#        U           1
# last   M         145
#        F          28
#        U           1
# mid    M         430
#        F         300
#        U          52
# Name: Gender, dtype: int64

# %%
Author0
# Out:
#          First        Second   Rank
# 0        linyi           gao  first  \
# 1           l.       aravind   last
# 2       nitzan           tal  first
# 3           r.       hendrix  first
# 4           g.       hatfull   last
# 5       januka  athukoralage  first
# 6       peiyin            ho  first
# 7           l.       aravind  first
# 8           a.     burroughs   last
# 9   lottariina      sundberg   last
# 10     libusha         kelly   last
# 11      januka  athukoralage  first
# 12   mindaugas       zaremba  first
# 13  virginijus       siksnys   last
# 14     zhifeng          zeng  first
# 15     wenyuan           han   last
# 16          a.         betts  first
# 17        k.c.          king   last
# 18      shiwei          wang  first
# 19    lianrong          wang   last
# 20      nitzan           tal  first
# 21       linyi           gao  first
# 22    xiaogang         cheng  first
# 23          r.       slavcev  first
# 24          s.         hayes   last
# 25          d.         parma  first
# 26          l.          gold   last
# 27   mitsunori          koga  first
# 28          l.       aravind   last
# 29          s.          bari  first
# 30     guilhem         faure  first
# 31        pere        puigbo  first
# 32      sukrit         silas  first
# 33      qunxin           she   last
# 34    lianrong          wang  first
# 35      shiwei          wang  first
# 36    lianrong          wang   last
# 37     xiaolin         xiong  first
# 38    lianrong          wang   last
# 39          c.       schmitt  first
# 40          i.      molineux   last
# 41          g.      kaufmann  first
# 42      januka  athukoralage  first
# 43      nitzan           tal  first
# 44      januka  athukoralage  first
# 45          y.            yu  first
# 46          l.        snyder   last
# 47          d.      rawlings  first
# 48      sukrit         silas  first
# 49  lottariina      sundberg   last
# 50     ziqiang         zheng  first
# 51     donghai          peng   last
# 52  kommireddy          vasu  first
# 53   valakunja      nagaraja   last
# 54       jurre        steens  first
# 55          pu           gao   last
# 56    marieeve        dupuis  first
#
#                                                 Title  isin_db Gender
# 0   Diverse enzymatic activities mediate antiviral...      0.0      M
# 1   CARF and WYL domains: ligand-binding regulator...      0.0      M
# 2   Cyclic CMP and cyclic UMP mediate bacterial im...      0.0      F
# 3   Evolutionary relationships among diverse bacte...      0.0      M
# 4   Evolutionary relationships among diverse bacte...      0.0      M
# 5   The dynamic interplay of host and viral enzyme...      0.0      M
# 6   Bacteriophage anti-defense genes that neutrali...      0.0      F
# 7   Discovering Biological Conflict Systems Throug...      0.0      M
# 8   Discovering Biological Conflict Systems Throug...      0.0      M
# 9   Mucin induces CRISPR-Cas defense in an opportu...      0.0      F
# 10  Resolving the structure of phagebacteria inte...      0.0      F
# 11  An anti-CRISPR viral ring nuclease subverts ty...      0.0      M
# 12  Sir2-domain associated short prokaryotic Argon...      0.0      M
# 13  Sir2-domain associated short prokaryotic Argon...      0.0      M
# 14  A short prokaryotic Argonaute activates membra...      0.0      M
# 15  A short prokaryotic Argonaute activates membra...      0.0      M
# 16  High Parasite Diversity Accelerates Host Adapt...      0.0      M
# 17  High Parasite Diversity Accelerates Host Adapt...      0.0      F
# 18  SspABCD-SspFGH Constitutes a New Type of DNA P...      0.0      M
# 19  SspABCD-SspFGH Constitutes a New Type of DNA P...      0.0      F
# 20  Bacteria deplete deoxynucleotides to defend ag...      0.0      F
# 21  Prokaryotic innate immunity through pattern re...      0.0      M
# 22  F exclusion of bacteriophage T7 occurs at the ...      0.0      M
# 23  Stationary phase-like properties of the bacter...      0.0      M
# 24  Stationary phase-like properties of the bacter...      0.0      F
# 25  The Rex system of bacteriophage lambda: tolera...      0.0      M
# 26  The Rex system of bacteriophage lambda: tolera...      0.0      U
# 27  Escherichia coli rnlA and rnlB Compose a Novel...      0.0      M
# 28  Comprehensive analysis of the HEPN superfamily...      0.0      M
# 29  A unique mode of nucleic acid immunity perform...      0.0      M
# 30  CRISPR-Cas in mobile genetic elements: counter...      0.0      M
# 31  Reconstruction of the evolution of microbial d...      0.0      M
# 32  Type III CRISPR-Cas systems can provide redund...      0.0      M
# 33  A novel interference mechanism by a type IIIB ...      0.0      M
# 34  DNA phosphorothioate modification-a new multi-...      0.0      F
# 35  SspABCD-SspFGH Constitutes a New Type of DNA P...      0.0      M
# 36  SspABCD-SspFGH Constitutes a New Type of DNA P...      0.0      F
# 37  SspABCD-SspE is a phosphorothioation-sensing b...      0.0      M
# 38  SspABCD-SspE is a phosphorothioation-sensing b...      0.0      F
# 39  Genes 1.2 and 10 of bacteriophages T3 and T7 d...      0.0      F
# 40  Genes 1.2 and 10 of bacteriophages T3 and T7 d...      0.0      M
# 41                                Anticodon nucleases      0.0      M
# 42  Cyclic Nucleotide Signaling in Phage Defense a...      0.0      M
# 43  Cyclic CMP and cyclic UMP mediate bacterial im...      0.0      F
# 44  The dynamic interplay of host and viral enzyme...      0.0      M
# 45  Translation elongation factor Tu cleaved by a ...      0.0      U
# 46  Translation elongation factor Tu cleaved by a ...      0.0      F
# 47  Proteic toxin-antitoxin, bacterial plasmid add...      0.0      M
# 48  Type III CRISPR-Cas systems can provide redund...      0.0      M
# 49  Cooperation between Different CRISPR-Cas Types...      0.0      F
# 50  The CRISPR-Cas systems were selectively inacti...      0.0      M
# 51  The CRISPR-Cas systems were selectively inacti...      0.0      M
# 52  Diverse functions of restriction-modification ...      0.0      M
# 53  Diverse functions of restriction-modification ...      0.0      M
# 54  The diverse arsenal of type III CRISPRCas-ass...      0.0      M
# 55  Molecular basis of RADAR anti-phage supramolec...      0.0      M
# 56  CRISPR-Cas and restrictionmodification system...      0.0      F
